# %%
from distribution_moments import LogNormalMoments

# %%
mu = 0
sigma2s = [0.2, 0, -1, 15]
for sigma2 in sigma2s:
    try:
        lognorm = LogNormalMoments(mu, sigma2)
    except ValueError as e:
        print(e)
        print("OK")
# Out:
# σ^2 must be positive.
# OK
# σ^2 must be positive.
# OK
